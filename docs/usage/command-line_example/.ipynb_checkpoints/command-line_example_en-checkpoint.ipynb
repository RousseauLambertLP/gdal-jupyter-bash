# %%
# %%bash
#
# conda install gdal
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /data/geomet/afsslor/conda/envs/jupyter
#
#   added / updated specs:
#     - gdal
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     curl-7.71.1                |       he644dc0_2         141 KB  conda-forge
#     dbus-1.13.6                |       he372182_0         602 KB  conda-forge
#     freexl-1.0.5               |    h516909a_1002          46 KB  conda-forge
#     gdal-3.1.1                 |   py36hd60729c_0         1.4 MB  conda-forge
#     glib-2.65.0                |       h6f030ca_0         3.5 MB  conda-forge
#     gst-plugins-base-1.14.5    |       h0935bb2_2         6.8 MB  conda-forge
#     gstreamer-1.14.5           |       h36ae1b5_2         4.5 MB  conda-forge
#     krb5-1.17.1                |       hfafb76e_1         1.5 MB  conda-forge
#     libblas-3.8.0              |      17_openblas          11 KB  conda-forge
#     libcblas-3.8.0             |      17_openblas          11 KB  conda-forge
#     libcurl-7.71.1             |       hcdd3856_2         303 KB  conda-forge
#     libedit-3.1.20191231       |       h46ee950_1         122 KB  conda-forge
#     libgdal-3.1.1              |       h4ed0dcf_0        24.4 MB  conda-forge
#     liblapack-3.8.0            |      17_openblas          11 KB  conda-forge
#     libopenblas-0.3.10         |pthreads_hb3c22a3_2         7.8 MB  conda-forge
#     libpq-12.3                 |       h5513abc_0         2.6 MB  conda-forge
#     libssh2-1.9.0              |       hab1572f_4         225 KB  conda-forge
#     numpy-1.19.0               |   py36h7314795_0         5.2 MB  conda-forge
#     poppler-0.89.0             |       h4190859_1        13.4 MB  conda-forge
#     postgresql-12.3            |       h8573dbc_0         5.0 MB  conda-forge
#     qt-5.9.7                   |       h0c104cb_3        80.8 MB  conda-forge
#     tiledb-2.0.6               |       h8efa9f0_0         1.9 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       160.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   boost-cpp          conda-forge/linux-64::boost-cpp-1.72.0-h8e57a91_0
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h516909a_2
#   cairo              conda-forge/linux-64::cairo-1.16.0-hcf35c78_1003
#   cfitsio            conda-forge/linux-64::cfitsio-3.470-h3eac812_5
#   curl               conda-forge/linux-64::curl-7.71.1-he644dc0_2
#   freexl             conda-forge/linux-64::freexl-1.0.5-h516909a_1002
#   gdal               conda-forge/linux-64::gdal-3.1.1-py36hd60729c_0
#   geos               conda-forge/linux-64::geos-3.8.1-he1b5a44_0
#   geotiff            conda-forge/linux-64::geotiff-1.6.0-h05acad5_0
#   gettext            conda-forge/linux-64::gettext-0.19.8.1-hc5be6a0_1002
#   giflib             conda-forge/linux-64::giflib-5.2.1-h516909a_2
#   hdf4               conda-forge/linux-64::hdf4-4.2.13-hf30be14_1003
#   hdf5               conda-forge/linux-64::hdf5-1.10.6-nompi_h3c11f04_100
#   json-c             conda-forge/linux-64::json-c-0.13.1-hbfbb72e_1002
#   kealib             conda-forge/linux-64::kealib-1.4.13-h33137a7_1
#   krb5               conda-forge/linux-64::krb5-1.17.1-hfafb76e_1
#   libblas            conda-forge/linux-64::libblas-3.8.0-17_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.8.0-17_openblas
#   libcurl            conda-forge/linux-64::libcurl-7.71.1-hcdd3856_2
#   libdap4            conda-forge/linux-64::libdap4-3.20.6-h1d1bd15_0
#   libedit            conda-forge/linux-64::libedit-3.1.20191231-h46ee950_1
#   libgdal            conda-forge/linux-64::libgdal-3.1.1-h4ed0dcf_0
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-7.5.0-hdf63c60_6
#   libiconv           conda-forge/linux-64::libiconv-1.15-h516909a_1006
#   libkml             conda-forge/linux-64::libkml-1.3.0-hb574062_1011
#   liblapack          conda-forge/linux-64::liblapack-3.8.0-17_openblas
#   libnetcdf          conda-forge/linux-64::libnetcdf-4.7.4-nompi_h84807e1_104
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.10-pthreads_hb3c22a3_2
#   libpq              conda-forge/linux-64::libpq-12.3-h5513abc_0
#   libspatialite      conda-forge/linux-64::libspatialite-4.3.0a-h2482549_1038
#   libssh2            conda-forge/linux-64::libssh2-1.9.0-hab1572f_4
#   libtiff            conda-forge/linux-64::libtiff-4.1.0-hc7e4089_6
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.1.0-h516909a_3
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.2-he1b5a44_1
#   numpy              conda-forge/linux-64::numpy-1.19.0-py36h7314795_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.3.1-h981e76c_3
#   pixman             conda-forge/linux-64::pixman-0.38.0-h516909a_1003
#   poppler            conda-forge/linux-64::poppler-0.89.0-h4190859_1
#   poppler-data       conda-forge/noarch::poppler-data-0.4.9-1
#   postgresql         conda-forge/linux-64::postgresql-12.3-h8573dbc_0
#   proj               conda-forge/linux-64::proj-7.0.0-h966b41f_4
#   tbb                conda-forge/linux-64::tbb-2020.1-hc9558a2_0
#   tiledb             conda-forge/linux-64::tiledb-2.0.6-h8efa9f0_0
#   tzcode             conda-forge/linux-64::tzcode-2020a-h516909a_0
#   xerces-c           conda-forge/linux-64::xerces-c-3.2.2-h8412b87_1004
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h14c3975_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.0.10-h516909a_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.3-h84519dc_1000
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.6.9-h516909a_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h516909a_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.10-h516909a_1002
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h14c3975_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h14c3975_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h14c3975_1007
#   zstd               conda-forge/linux-64::zstd-1.4.4-h6597ccf_3
#
# The following packages will be UPDATED:
#
#   fontconfig         anaconda::fontconfig-2.13.0-h9420a91_0 --> conda-forge::fontconfig-2.13.1-h86ecdb6_1001
#   glib                     anaconda::glib-2.56.2-hd408876_0 --> conda-forge::glib-2.65.0-h6f030ca_0
#   gst-plugins-base   anaconda::gst-plugins-base-1.14.0-hbb~ --> conda-forge::gst-plugins-base-1.14.5-h0935bb2_2
#   gstreamer           anaconda::gstreamer-1.14.0-hb453b48_1 --> conda-forge::gstreamer-1.14.5-h36ae1b5_2
#   icu                         anaconda::icu-58.2-he6710b0_3 --> conda-forge::icu-64.2-he1b5a44_1
#   jpeg                         anaconda::jpeg-9b-habf39ab_1 --> conda-forge::jpeg-9d-h516909a_0
#   libuuid                anaconda::libuuid-1.0.3-h1bed415_2 --> conda-forge::libuuid-2.32.1-h14c3975_1000
#   qt                          anaconda::qt-5.9.7-h5867ecd_1 --> conda-forge::qt-5.9.7-h0c104cb_3
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates     anaconda::ca-certificates-2020.6.24-0 --> conda-forge::ca-certificates-2020.6.20-hecda079_0
#   certifi                anaconda::certifi-2020.6.20-py36_0 --> conda-forge::certifi-2020.6.20-py36h9f0ad1d_0
#   dbus                    anaconda::dbus-1.13.12-h746ee38_0 --> conda-forge::dbus-1.13.6-he372182_0
#   libxml2               anaconda::libxml2-2.9.10-he19cac6_1 --> conda-forge::libxml2-2.9.10-hee79883_0
#   openssl               anaconda::openssl-1.1.1g-h7b6447c_0 --> conda-forge::openssl-1.1.1g-h516909a_0
#
#
# Proceed ([y]/n)?
#
# Downloading and Extracting Packages
# gst-plugins-base-1.1 | 6.8 MB    | ########## | 100%
# dbus-1.13.6          | 602 KB    | ########## | 100%
# gstreamer-1.14.5     | 4.5 MB    | ########## | 100%
# glib-2.65.0          | 3.5 MB    | ########## | 100%
# tiledb-2.0.6         | 1.9 MB    | ########## | 100%
# numpy-1.19.0         | 5.2 MB    | ########## | 100%
# krb5-1.17.1          | 1.5 MB    | ########## | 100%
# libcurl-7.71.1       | 303 KB    | ########## | 100%
# curl-7.71.1          | 141 KB    | ########## | 100%
# liblapack-3.8.0      | 11 KB     | ########## | 100%
# libcblas-3.8.0       | 11 KB     | ########## | 100%
# postgresql-12.3      | 5.0 MB    | ########## | 100%
# libgdal-3.1.1        | 24.4 MB   | ########## | 100%
# gdal-3.1.1           | 1.4 MB    | ########## | 100%
# libpq-12.3           | 2.6 MB    | ########## | 100%
# libssh2-1.9.0        | 225 KB    | ########## | 100%
# freexl-1.0.5         | 46 KB     | ########## | 100%
# libopenblas-0.3.10   | 7.8 MB    | ########## | 100%
# libblas-3.8.0        | 11 KB     | ########## | 100%
# poppler-0.89.0       | 13.4 MB   | ########## | 100%
# qt-5.9.7             | 80.8 MB   | ########## | 100%
# libedit-3.1.20191231 | 122 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# %%bash
#
# gdalinfo --version
# Out:
# GDAL 3.1.1, released 2020/06/22

# %%
# %%bash
#
# wget -nd -np -r -R "*index.html*" -A "*TMP_TGL_2*.grib2" https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/
# Out:
# --2020-07-17 18:06:31--  https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/
# Resolving dd.weather.gc.ca (dd.weather.gc.ca)... 205.189.10.47
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.tmp.2’
#
#      0K .......... .......... .......... .......... ..........  114M
#     50K ........                                                139M=0s
#
# 2020-07-17 18:06:31 (117 MB/s) - ‘index.html.tmp.2’ saved [60312]
#
# Loading robots.txt; please ignore errors.
# --2020-07-17 18:06:31--  https://dd.weather.gc.ca/robots.txt
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-07-17 18:06:31 ERROR 404: Not Found.
#
# Removing index.html.tmp.2 since it should be rejected.
#
# --2020-07-17 18:06:31--  https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/?C=N;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=N;O=D.tmp’
#
#      0K .......... .......... .......... .......... .......... 60.4M
#     50K ........                                               71.5M=0.001s
#
# 2020-07-17 18:06:32 (61.8 MB/s) - ‘index.html?C=N;O=D.tmp’ saved [60312]
#
# Removing index.html?C=N;O=D.tmp since it should be rejected.
#
# --2020-07-17 18:06:32--  https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/?C=M;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=M;O=A.tmp’
#
#      0K .......... .......... .......... .......... .......... 49.9M
#     50K ........                                               64.4M=0.001s
#
# 2020-07-17 18:06:32 (51.6 MB/s) - ‘index.html?C=M;O=A.tmp’ saved [60312]
#
# Removing index.html?C=M;O=A.tmp since it should be rejected.
#
# --2020-07-17 18:06:32--  https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/?C=S;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=S;O=A.tmp’
#
#      0K .......... .......... .......... .......... .......... 13.2M
#     50K ........                                               34.8M=0.004s
#
# 2020-07-17 18:06:32 (14.6 MB/s) - ‘index.html?C=S;O=A.tmp’ saved [60312]
#
# Removing index.html?C=S;O=A.tmp since it should be rejected.
#
# --2020-07-17 18:06:32--  https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/?C=D;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=D;O=A.tmp’
#
#      0K .......... .......... .......... .......... .......... 57.8M
#     50K ........                                               68.2M=0.001s
#
# 2020-07-17 18:06:32 (59.2 MB/s) - ‘index.html?C=D;O=A.tmp’ saved [60312]
#
# Removing index.html?C=D;O=A.tmp since it should be rejected.
#
# --2020-07-17 18:06:32--  https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/CMC_glb_TMP_TGL_2_latlon.15x.15_2020071700_P000.grib2
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1053384 (1.0M)
# Saving to: ‘CMC_glb_TMP_TGL_2_latlon.15x.15_2020071700_P000.grib2’
#
#      0K .......... .......... .......... .......... ..........  4% 32.0M 0s
#     50K .......... .......... .......... .......... ..........  9% 50.7M 0s
#    100K .......... .......... .......... .......... .......... 14% 50.2M 0s
#    150K .......... .......... .......... .......... .......... 19% 42.9M 0s
#    200K .......... .......... .......... .......... .......... 24% 52.6M 0s
#    250K .......... .......... .......... .......... .......... 29% 42.5M 0s
#    300K .......... .......... .......... .......... .......... 34% 71.6M 0s
#    350K .......... .......... .......... .......... .......... 38% 83.7M 0s
#    400K .......... .......... .......... .......... .......... 43% 44.7M 0s
#    450K .......... .......... .......... .......... .......... 48% 74.3M 0s
#    500K .......... .......... .......... .......... .......... 53% 70.4M 0s
#    550K .......... .......... .......... .......... .......... 58%  177M 0s
#    600K .......... .......... .......... .......... .......... 63%  163M 0s
#    650K .......... .......... .......... .......... .......... 68%  134M 0s
#    700K .......... .......... .......... .......... .......... 72%  116M 0s
#    750K .......... .......... .......... .......... .......... 77%  104M 0s
#    800K .......... .......... .......... .......... .......... 82%  100M 0s
#    850K .......... .......... .......... .......... .......... 87%  111M 0s
#    900K .......... .......... .......... .......... .......... 92%  141M 0s
#    950K .......... .......... .......... .......... .......... 97%  161M 0s
#   1000K .......... .......... ........                        100%  228M=0.01s
#
# 2020-07-17 18:06:32 (72.2 MB/s) - ‘CMC_glb_TMP_TGL_2_latlon.15x.15_2020071700_P000.grib2’ saved [1053384/1053384]
#
# --2020-07-17 18:06:32--  https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/?C=N;O=A
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=N;O=A.tmp’
#
#      0K .......... .......... .......... .......... .......... 56.6M
#     50K ........                                               66.3M=0.001s
#
# 2020-07-17 18:06:32 (57.9 MB/s) - ‘index.html?C=N;O=A.tmp’ saved [60312]
#
# Removing index.html?C=N;O=A.tmp since it should be rejected.
#
# --2020-07-17 18:06:32--  https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/?C=M;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=M;O=D.tmp’
#
#      0K .......... .......... .......... .......... .......... 58.3M
#     50K ........                                               72.7M=0.001s
#
# 2020-07-17 18:06:32 (60.1 MB/s) - ‘index.html?C=M;O=D.tmp’ saved [60312]
#
# Removing index.html?C=M;O=D.tmp since it should be rejected.
#
# --2020-07-17 18:06:32--  https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/?C=S;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=S;O=D.tmp’
#
#      0K .......... .......... .......... .......... .......... 67.9M
#     50K ........                                               75.2M=0.001s
#
# 2020-07-17 18:06:32 (68.9 MB/s) - ‘index.html?C=S;O=D.tmp’ saved [60312]
#
# Removing index.html?C=S;O=D.tmp since it should be rejected.
#
# --2020-07-17 18:06:32--  https://dd.weather.gc.ca/model_gem_global/15km/grib2/lat_lon/00/000/?C=D;O=D
# Connecting to dd.weather.gc.ca (dd.weather.gc.ca)|205.189.10.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html?C=D;O=D.tmp’
#
#      0K .......... .......... .......... .......... .......... 60.6M
#     50K ........                                               70.6M=0.001s
#
# 2020-07-17 18:06:32 (61.9 MB/s) - ‘index.html?C=D;O=D.tmp’ saved [60312]
#
# Removing index.html?C=D;O=D.tmp since it should be rejected.
#
# FINISHED --2020-07-17 18:06:32--
# Total wall clock time: 0.7s
# Downloaded: 10 files, 1.5M in 0.03s (60.7 MB/s)

# %%
# %%bash
#
# gdalinfo -mm -proj4 CMC_glb_TMP_TGL_2*
# Out:
# Driver: GRIB/GRIdded Binary (.grb, .grb2)
# Files: CMC_glb_TMP_TGL_2_latlon.15x.15_2020071700_P000.grib2
# Size is 2400, 1201
# Coordinate System is:
# GEOGCRS["Coordinate System imported from GRIB file",
#     DATUM["unnamed",
#         ELLIPSOID["Sphere",6371229,0,
#             LENGTHUNIT["metre",1,
#                 ID["EPSG",9001]]]],
#     PRIMEM["Greenwich",0,
#         ANGLEUNIT["degree",0.0174532925199433,
#             ID["EPSG",9122]]],
#     CS[ellipsoidal,2],
#         AXIS["latitude",north,
#             ORDER[1],
#             ANGLEUNIT["degree",0.0174532925199433,
#                 ID["EPSG",9122]]],
#         AXIS["longitude",east,
#             ORDER[2],
#             ANGLEUNIT["degree",0.0174532925199433,
#                 ID["EPSG",9122]]]]
# Data axis to CRS axis mapping: 2,1
# PROJ.4 string is:
# '+proj=longlat +R=6371229 +no_defs'
# Origin = (-180.074999999999989,90.075000000000003)
# Pixel Size = (0.150000000000000,-0.150000000000000)
# Corner Coordinates:
# Upper Left  (-180.0750000,  90.0750000) (180d 4'30.00"W, 90d 4'30.00"N)
# Lower Left  (-180.0750000, -90.0750000) (180d 4'30.00"W, 90d 4'30.00"S)
# Upper Right ( 179.9250000,  90.0750000) (179d55'30.00"E, 90d 4'30.00"N)
# Lower Right ( 179.9250000, -90.0750000) (179d55'30.00"E, 90d 4'30.00"S)
# Center      (  -0.0750000,   0.0000000) (  0d 4'30.00"W,  0d 0' 0.01"N)
# Band 1 Block=2400x1 Type=Float64, ColorInterp=Undefined
#   Description = 2[m] HTGL="Specified height level above ground"
#     Computed Min/Max=-65.451,43.699
#   Metadata:
#     GRIB_COMMENT=Temperature [C]
#     GRIB_DISCIPLINE=0(Meteorological)
#     GRIB_ELEMENT=TMP
#     GRIB_FORECAST_SECONDS=0 sec
#     GRIB_IDS=CENTER=54(Montreal) SUBCENTER=0 MASTER_TABLE=4 LOCAL_TABLE=0 SIGNF_REF_TIME=1(Start_of_Forecast) REF_TIME=2020-07-17T00:00:00Z PROD_STATUS=0(Operational) TYPE=2(Analysis_and_forecast)
#     GRIB_PDS_PDTN=0
#     GRIB_PDS_TEMPLATE_ASSEMBLED_VALUES=0 0 2 47 47 0 0 1 0 103 0 2 255 -127 -2147483647
#     GRIB_PDS_TEMPLATE_NUMBERS=0 0 2 47 47 0 0 0 1 0 0 0 0 103 0 0 0 0 2 255 255 255 255 255 255
#     GRIB_REF_TIME=  1594944000 sec UTC
#     GRIB_SHORT_NAME=2-HTGL
#     GRIB_UNIT=[C]
#     GRIB_VALID_TIME=  1594944000 sec UTC
